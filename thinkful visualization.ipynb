# %%
import os
os.getcwd()
import pandas as pd
import numpy as np
from operator import itemgetter
# %matplotlib inline
import matplotlib.pyplot as plt
from collections import Counter

# %%
df=pd.read_csv('party_in_nyc.csv')

# %%
df.head()
# Out:
#           Created Date          Closed Date               Location Type  \
# 0  2015-12-31 00:01:15  2015-12-31 03:48:04            Store/Commercial
# 1  2015-12-31 00:02:48  2015-12-31 04:36:13            Store/Commercial
# 2  2015-12-31 00:03:25  2015-12-31 00:40:15  Residential Building/House
# 3  2015-12-31 00:03:26  2015-12-31 01:53:38  Residential Building/House
# 4  2015-12-31 00:05:10  2015-12-31 03:49:10  Residential Building/House
#
#    Incident Zip      City    Borough   Latitude  Longitude
# 0       10034.0  NEW YORK  MANHATTAN  40.866183 -73.918930
# 1       10040.0  NEW YORK  MANHATTAN  40.859324 -73.931237
# 2       10026.0  NEW YORK  MANHATTAN  40.799415 -73.953371
# 3       11231.0  BROOKLYN   BROOKLYN  40.678285 -73.994668
# 4       10033.0  NEW YORK  MANHATTAN  40.850304 -73.938516

# %%
df['Location Type'].unique()
# Out:
# array(['Store/Commercial', 'Residential Building/House',
#        'Club/Bar/Restaurant', 'Street/Sidewalk', 'Park/Playground',
#        'House of Worship'], dtype=object)

# %%
df['City'].unique()
# Out:
# array(['NEW YORK', 'BROOKLYN', 'BRONX', 'JACKSON HEIGHTS', 'FOREST HILLS',
#        'OZONE PARK', 'FLUSHING', 'ASTORIA', nan, 'CORONA', 'JAMAICA',
#        'FAR ROCKAWAY', 'RIDGEWOOD', 'STATEN ISLAND', 'KEW GARDENS',
#        'BAYSIDE', 'FRESH MEADOWS', 'WOODHAVEN', 'SOUTH OZONE PARK',
#        'EAST ELMHURST', 'LONG ISLAND CITY', 'QUEENS VILLAGE', 'SUNNYSIDE',
#        'SAINT ALBANS', 'WOODSIDE', 'HOWARD BEACH', 'ROCKAWAY PARK',
#        'LITTLE NECK', 'ARVERNE', 'ELMHURST', 'SOUTH RICHMOND HILL',
#        'MIDDLE VILLAGE', 'OAKLAND GARDENS', 'COLLEGE POINT', 'MASPETH',
#        'REGO PARK', 'RICHMOND HILL', 'HOLLIS', 'SPRINGFIELD GARDENS',
#        'CAMBRIA HEIGHTS', 'GLEN OAKS', 'WHITESTONE', 'BELLEROSE', 'QUEENS',
#        'ROSEDALE', 'NEW HYDE PARK', 'CENTRAL PARK', 'FLORAL PARK',
#        'BREEZY POINT'], dtype=object)

# %%
df['Borough'].unique()
# Out:
# array(['MANHATTAN', 'BROOKLYN', 'BRONX', 'QUEENS', 'Unspecified',
#        'STATEN ISLAND'], dtype=object)

# %%
plt.figure(figsize=(10,10))
pd.Series.sort_values(df['Location Type'], axis=0, ascending= True, inplace=False,kind='heapsort')
plt.hist(df['Location Type'],bins=10,alpha=0.5)
plt.ylabel('Counts')
# Out:
# Text(0,0.5,'Counts')

# %%
#As shown in the figure above, Buildings/Houses are the most popular locations that people like to throw parties.

# %%
plt.scatter(df['Latitude'], df['Longitude'], norm=0, vmin=None, vmax=None, alpha=0.5, linewidths=0.01)
plt.xlabel('Latitude')
plt.ylabel('Longitude')
plt.xlim(40.4,41)
#Queens, Bronx, uptown areas seem to have more parties.
# Out:
# (40.4, 41)

# %%
df['Closed Date'] = pd.to_datetime(df['Closed Date'])

# %%
df['Created Date'] = pd.to_datetime(df['Created Date'])

# %%
df['time_diff']= df['Closed Date']-df['Created Date']

# %%
df['time_diff'].head()

# %%
plt.figure(figsize=(20,10))
x = df['time_diff'] = pd.to_datetime(df['time_diff'])
y = df['Location Type']
plt.plot(y,x,alpha=0.5, linewidth=0.05)

# %%
#Durations for different location.

# %%
#Trying to figure out durations for parties at New York in 2016.

# %%
plt.figure(figsize=(10,10))
plt.xlabel('Borough')
plt.ylabel('City')
plt.title('Where incidents happen')
plt.ylim(25)
plt.scatter(df['Borough'], df['City'],alpha=0.1)#marker=r'$\clubsuit$'

# %%
#Winner is...Queens!
